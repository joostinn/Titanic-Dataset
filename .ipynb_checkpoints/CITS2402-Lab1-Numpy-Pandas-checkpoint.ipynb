# %% [markdown]
# ## <center>CITS2402 - Introduction to Data Science - Lab sheet 1 - Numpy and Pandas.</center>
#
# **File name: CITS2402-Lab1-Numpy-Pandas.ipynb**<br>
# **Date:** July 2025<br>
#
# In this notebook, you will do coding exercises to practice Numpy and Pandas and start some basic data analysis using different datasets. The exercises include:
#   - [Numpy slicing](#numpy_slicing)
#   - [Boolean indexing](#boolean_indexing)
#   - [Vectorised computation](#vectorised_computation)
#   - [Performing data-related queries on the USA state coordinates](#dataset_usa)
#   - [Performing data-related queries on the Titanic dataset](#dataset_titanic)
#   - [Practicing data tidying](#data_tidying)

# %%
#importing the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ### Part 1: Numpy slicing
# <a id=numpy_slicing></a>

# %% [markdown]
# **Task 1:** Create a Numpy array containing three rows and three columns. That is, your array should have shape (3,3). Suggestion: explore the Numpy function `np.random.randn()`

# %%
# your code here

# %% [markdown]
# **Task 2:** Create Python code that will do the slice to reproduce as result the required **shape** as follows:
# > 1. (2, 2)
# > 2. (3, )
# > 3. (3, 2)
# > 4. (1, 2)
# > 5. (1, 3)

# %%
# your code here

# %% [markdown]
# **Task 3:** Create a code to exemplify that assigning to a slice expression assigns to the whole selection.

# %%
# your code here

# %% [markdown]
# ### Part 2: Boolean indexing
# <a id=boolean_indexing></a>

# %% [markdown]
# You have a toy dataset representing the temperatures (in degrees Celsius) recorded over a month (30 days) in three different cities. Your task is to use boolean indexing to perform various operations on this dataset using Numpy.

# %%
# Temperatures for City A, City B, and City C over 30 days
temperatures = np.array([ [22, 25, 28], [21, 24, 27], [19, 22, 25], [23, 26, 29], [20, 23, 26], 
                         [18, 21, 24], [17, 20, 23], [25, 28, 31], [26, 29, 32], [24, 27, 30], 
                         [22, 25, 28], [21, 24, 27], [19, 22, 25], [23, 26, 29], [20, 23, 26], 
                         [18, 21, 24], [17, 20, 23], [25, 28, 31], [26, 29, 32], [24, 27, 30], 
                         [22, 25, 28], [21, 24, 27], [19, 22, 25], [23, 26, 29], [20, 23, 26], 
                         [18, 21, 24], [17, 20, 23], [25, 28, 31], [26, 29, 32], [24, 27, 30] ])

# %% [markdown]
# **Task 1:** Find all days where the temperature in City A was above 20 degrees.

# %%
# Your code here

# %% [markdown]
# **Task 2:** Find the average temperature for City B on days where the temperature in City C was above 30 degrees.

# %%
# Your code here

# %% [markdown]
# **Task 3**: Identify the days when the temperature in all three cities was below 25 degrees.

# %%
# Your code here

# %% [markdown]
# **Task 4:** Replace all temperatures below 20 degrees with 20 degrees.

# %%
# Your code here

# %% [markdown]
# **Task 5:** Count the number of days where the temperature in City B was between 24 and 28 degrees (inclusive).

# %%
# Your code here

# %% [markdown]
# ### Part 3: Vectorised computation with Numpy
# <a id=vectorised_computation></a>

# %% [markdown]
# Below is a toy dataset representing the sales data for a small store over seven days. The dataset includes the number of units sold for three products (Product A, Product B, and Product C). Your task is to perform various vectorised computations on this dataset using Numpy.

# %%
# Units sold for Product A, B, and C over 7 days
units_sold = np.array([
    [20, 35, 50],
    [25, 40, 55],
    [30, 45, 60],
    [35, 50, 65],
    [40, 55, 90],
    [45, 60, 75],
    [50, 65, 80]
])

# Prices of Product A, B, and C
prices = np.array([10, 15, 20])

# %% [markdown]
# **Tasks:** Write Python code using vectorised computation to calculate:
#
# > 1) The total units sold for each product over the week. </br>
# > 2) The daily revenue for each product. </br>
# > 3) The total revenue for each product over the week. </br>
# > 4) The average daily units sold for each product. </br>
# > 5) The highest total sales (units) for each product. </br>
# > 6) Apply a 10% discount to all prices and recalculate the total weekly revenue for each product.

# %%
# your code here

# %% [markdown]
# ### Part 4: USA states coordinates
# <a id=dataset_usa></a>

# %% [markdown]
# **Task 1:** Using the same approach to compute "closeness" as in the lecture example using countries coordinates (chord distance), read the coordinates of US states from `usa_states.csv` and create Python code using Numpy and Pandas functionalities to discover, according to this data, the following:
#
# > 1) The closest state to the US capital - Washington DC. </br>
# > 2) Which states are within 100km of the US capital? What may the coordinates be representing? </br>
# > 3) What is the farthest distance between any two US states, rounded to three decimal places?
#
# Hint 1: To compute the Euclidean distance, investigate what the Numpy function `linalg.norm` does. :)
#
# Hint 2: Have a look at Numpy `np.newaxis_` to do the broadcasting trick. :)

# %%
# your code here

# %% [markdown]
# **Task 2:** Let's integrate the countries dataset and the US states dataset. Use Numpy to show the names of 10 countries closest to the US capital - Washington DC, and print a Numpy array containing the coordinates of these closest 10 countries.
#
# Hint: Practice using the `concatenate()` function from Numpy to stack the coordinates of the top 10 countries.
#
# Make sure you correct the issues in the countries dataset we discovered in the lecture!
#
# Have you noticed something curious about the result? :) How can analysing these results help us to define the questions better?

# %%
# your code here

# %% [markdown]
# ### Part 5: The Titanic dataset
# <a id=dataset_titanic></a>
#
# For this part, we will use a **modified** version of the Titanic dataset. It is provided in the file `titanic.csv`. More information about the (original) dataset can be found at https://www.kaggle.com/c/titanic/data

# %% [markdown]
# **Part 5.1: Overview of the dataset.**
#
# **Task 1:** Load the dataset using a Pandas Dataframe.

# %%
# your code here

# %% [markdown]
# **Task 2:** Display the first 5 rows.

# %%
# your code here

# %% [markdown]
# **Task 3:** Ensure you know what each row (example/instance/observation) and the different columns (features) mean. After investigating the dataset, compute the number of features or characteristics and the number of observations.

# %%
# your code here

# %% [markdown]
# **Task 4:** What are the different data types?

# %%
# your code here

# %% [markdown]
# **Task 5:** Display the summary statistics of the dataset. Did you notice anything strange?

# %%
# your code here

# %% [markdown]
# **Task 6:** Are there missing values in this dataset? If so, in which column(s)? What about duplicated instances? Can we consider them as duplications in this case?

# %%
# your code here

# %% [markdown]
# **Task 7:** What are the unique values of the categorical features?

# %%
# your code here

# %% [markdown]
# **Part 5.2: Initial data exploration and manipulation with Pandas.**
#
# **Task 1:** Create a new column (feature) `family_size`, which is the sum of `sibsp` and `parch`.

# %%
# your code here

# %% [markdown]
# **Task 2:** Formulate general data exploration questions about the Titanic dataset.
#
# Example questions (but we encourage you to think about other ones too):
#
# > What is the overall survival rate on the Titanic? </br>
# > What is the number of passengers by class? </br>
# > What is the survival rate by gender? </br>
# > What are the average age and fare of the passengers? </br>
# > What is the average fare paid by each class?
#
# How would you prepare the data for analysis?
#
# When processing the data, it's important to describe the steps you take. Even if you're using a simple solution to handle missing values, incorrect values, or duplications, always state your assumptions and rationale for these decisions. This transparency will help others understand your thought process. Remember the traits of a good data scientist.
#
# Pay attention to how these decisions affect the results. Also, understand how the different Python functions deal with missing values or NAN values. For instance, how does `pd.mean()` deal with missing values to calculate the mean?
#
# If you find any data issues on Task 5 of Part 5.1, create code to address them before addressing your questions.

# %%
#your code/answer here

# %% [markdown]
# **Task 3:** Perform a basic analysis using Pandas to answer your question(s). You can include visualisations.

# %%
#your code here

# %% [markdown]
# #### Extension questions:
#
# > 1) What is the survival rate of passengers travelling with family compared to those travelling alone? </br>
# > Hint: You may need to create a new feature, `traveling_alone,` to indicate whether a passenger is travelling alone or with family.

# %%
# your code here

# %% [markdown]
# > 2) What is the survival rate by age group? </br>
# > Group passengers into age bins (e.g., children, adults, seniors) and calculate the survival rate for each group.

# %%
# your code here

# %% [markdown]
# ### Part 6: Data tidying
# <a id=data_tidying></a>
#
# **Task 1:** For this part, we work on the example basketball dataset discussed in the lecture. Your task is to create a Python code using Pandas that generates the following table from table 1 and table 2:

# %% [markdown]
# | Player  | Season | Games Played | Total Points | Points per Game |
# |---------|--------|--------------|---------------|------------------|
# | Jordan  | 2019   | 60           | 1500          | 25.0             |
# | Jordan  | 2020   | 58           | 1392          | 24.0             |
# | Kobe    | 2019   | 70           | 1960          | 28.0             |
# | Kobe    | 2020   | 65           | 1820          | 28.0             |
# | LeBron  | 2019   | 55           | 1485          | 27.0             |
# | LeBron  | 2020   | 60           | 1680          | 28.0             |

# %%
table1 = pd.DataFrame({
    'player': [
        'Jordan', 'Jordan', 'Jordan', 'Jordan',
        'Kobe', 'Kobe', 'Kobe', 'Kobe',
        'LeBron', 'LeBron', 'LeBron', 'LeBron'
    ],
    'season': [
        2019, 2019, 2020, 2020,
        2019, 2019, 2020, 2020,
        2019, 2019, 2020, 2020
    ],
    'metric': [
        'games_played', 'total_points', 'games_played', 'total_points',
        'games_played', 'total_points', 'games_played', 'total_points',
        'games_played', 'total_points', 'games_played', 'total_points'
    ],
    'value': [
        60, 1500, 58, 1392,
        70, 1960, 65, 1820,
        55, 1485, 60, 1680
    ]
})

table1

# %%
table2 = pd.DataFrame({
    'player': ['Jordan', 'Jordan', 'Kobe', 'Kobe', 'LeBron', 'LeBron'],
    'season': [2019, 2020, 2019, 2020, 2019, 2020],
    'points_per_game': [
        round(1500 / 60, 1),
        round(1392 / 58, 1),
        round(1960 / 70, 1),
        round(1820 / 65, 1),
        round(1485 / 55, 1),
        round(1680 / 60, 1)
    ]
})

table2

# %% [markdown]
# Hint: There are many ways to do that, but you may learn a different way by checking what Pandas function `pivot()` does. :)

# %%
# your code here

# %% [markdown]
# **Task 2:** Consider following dataset:
#
# | Player  | Season | GP_Regular | GP_Playoffs | Points_Regular | Points_Playoffs |
# |---------|--------|------------|--------------|----------------|------------------|
# | Jordan  | 2019   | 60         | 10           | 1500           | 320              |
# | Jordan  | 2020   | 58         | 12           | 1392           | 290              |
# | Kobe    | 2019   | 70         | 15           | 1960           | 410              |
# | Kobe    | 2020   | 65         | 8            | 1820           | 220              |
#
#
# - Tidy the data so that each observation (e.g. player in a season and game type) is a row.
# - Create a new column _points_per_game_ for each entry, rounded to three decimal places.
# - GP stands for 'Games Played'.

# %%
data = pd.DataFrame({
    'Player': ['Jordan', 'Jordan', 'Kobe', 'Kobe'],
    'Season': [2019, 2020, 2019, 2020],
    'GP_Regular': [60, 58, 70, 65],
    'GP_Playoffs': [10, 12, 15, 8],
    'Points_Regular': [1500, 1392, 1960, 1820],
    'Points_Playoffs': [320, 290, 410, 220]
})

# your code here
